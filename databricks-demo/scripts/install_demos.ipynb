# %%
# %%capture
# %pip install dbdemos

# %%
import dbdemos
dbdemos.list_demos()

# %%
dbdemos.help()

# %%
dbdemos.install(
    'lakehouse-fsi-credit',
    catalog="demos",
    schema="lakehouse_hls_readmission",
    serverless=True,
    warehouse_name="Serverless Starter Warehouse",
    path="./",
    overwrite=True,
    use_current_cluster=True,
    skip_dashboards=False,
    skip_genie_rooms=False
)
