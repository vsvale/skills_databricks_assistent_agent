# %%
from pyspark.sql.types import *
from pyspark.sql import DataFrame

# %%
schema_bronze_back = StructType([
    StructField("_id", StringType(), True),
    StructField("attributes", StringType(), True),
    StructField("date", StringType(), True),
    StructField("host", StringType(), True),
    StructField("message", StringType(), True),
    StructField("source", StringType(), True),
    StructField("status", StringType(), True),
    StructField("tags", ArrayType(StringType()), True),
    StructField("hour", IntegerType(), True)
])

# %%
schema_bronze_front = StructType([
    StructField("_id", StringType(), False),
    StructField("attributes", StringType(), False),    
    StructField("date", StringType(), False),
    StructField("message", StringType(), False),
    StructField("service", StringType(), False),
    StructField("source", StringType(), False),
    StructField("status", StringType(), False),
    StructField("tags", StructType([
        StructField("element", StringType(), False)
    ]), False)
])

# %%
attributes_front_schema =  StructType([
                        StructField("_dd", StructType([
                            StructField("device", StructType([
                                StructField("architecture", StringType(), False),
                                StructField("brand", StringType(), False),
                                StructField("model", StringType(), False),
                                StructField("name", StringType(), False)
                            ]), False)
                        ]), False),
                        StructField("ab_test", StructType([
                            StructField("3d_liveness", BooleanType(), False),
                            StructField("last_passwords", BooleanType(), False),
                            StructField("liveness", BooleanType(), False),
                            StructField("optional_label", BooleanType(), False),
                            StructField("password_document", BooleanType(), False),
                            StructField("password_number", BooleanType(), False),
                            StructField("password_prohibited_words", BooleanType(), False),
                            StructField("password_repeated_characters", BooleanType(), False),
                            StructField("password_size", BooleanType(), False),
                            StructField("password_with_capital_letter", BooleanType(), False),
                            StructField("password_with_lowercase_letter", BooleanType(), False),
                            StructField("password_with_name", BooleanType(), False),
                            StructField("password_with_sequential_characters", BooleanType(), False),
                            StructField("password_with_sequential_numbers", BooleanType(), False),
                            StructField("show_email", BooleanType(), False),
                            StructField("whatsapp_available", BooleanType(), False)
                        ]), False),
                        StructField("action", StringType(), False),
                        StructField("application_id", StringType(), False),
                        StructField("area", StringType(), False),
                        StructField("biometric_opt_in_result", StringType(), False),
                        StructField("build_version", StringType(), False),
                        StructField("capture_type", StringType(), False),
                        StructField("channel", StringType(), False),
                        StructField("check_result", StringType(), False),
                        StructField("date", StringType(), False),
                        StructField("dd-request-id", StringType(), False),
                        StructField("delay", StringType(), False),
                        StructField("destinationURL", StringType(), False),
                        StructField("did_inform_cellphone", BooleanType(), False),
                        StructField("did_inform_email", BooleanType(), False),
                        StructField("document_side", StringType(), False),
                        StructField("document_type", StringType(), False),
                        StructField("engine_status", StringType(), False),
                        StructField("error", StructType([
                            StructField("kind", StringType(), False),
                            StructField("message", StringType(), False),
                            StructField("origin", StringType(), False),
                            StructField("stack", StringType(), False)
                        ]), False),
                        StructField("error_description", StringType(), False),
                        StructField("error_key", StringType(), False),
                        StructField("error_message", StringType(), False),
                        StructField("error_status_code", StringType(), False),
                        StructField("error_type", StringType(), False),
                        StructField("errors_before_upload_count", StringType(), False),
                        StructField("eventCode", StringType(), False),
                        StructField("event_name", StringType(), False),
                        StructField("fetch_duration", StringType(), False),
                        StructField("flow", StringType(), False),
                        StructField("flow_origin", StringType(), False),
                        StructField("flow_time", LongType(), False),
                        StructField("flow_version", StringType(), False),
                        StructField("flowmessage", StringType(), False),
                        StructField("http", StructType([
                            StructField("useragent", StringType(), False),
                            StructField("useragent_details", StructType([
                                StructField("browser", StructType([
                                    StructField("family", StringType(), False),
                                    StructField("major", StringType(), False),
                                    StructField("minor", StringType(), False),
                                    StructField("patch", StringType(), False),
                                    StructField("patch_minor", StringType(), False)
                                ]), False),
                                StructField("device", StructType([
                                    StructField("brand", StringType(), False),
                                    StructField("category", StringType(), False),
                                    StructField("family", StringType(), False),
                                    StructField("model", StringType(), False)
                                ]), False),
                                StructField("os", StructType([
                                    StructField("family", StringType(), False),
                                    StructField("major", StringType(), False),
                                    StructField("minor", StringType(), False),
                                    StructField("patch", StringType(), False)
                                ]), False)
                            ]), False)
                        ]), False),
                        StructField("is_redirecting_to_account_recovery", StringType(), False),
                        StructField("legalize_data", StructType([
                            StructField("birthdate", BooleanType(), False),
                            StructField("cellphone", BooleanType(), False),
                            StructField("email", BooleanType(), False),
                            StructField("name", BooleanType(), False)
                        ]), False),
                        StructField("log_type", StringType(), False),
                        StructField("logger", StructType([
                            StructField("name", StringType(), False),
                            StructField("thread_name", StringType(), False),
                            StructField("version", StringType(), False)
                        ]), False),
                        StructField("logger_type", StringType(), False),
                        StructField("login_api_time", LongType(), False),
                        StructField("login_from", StringType(), False),
                        StructField("login_type", StringType(), False),
                        StructField("method", StringType(), False),
                        StructField("needs_unlock", BooleanType(), False),
                        StructField("network", StructType([
                            StructField("client", StructType([
                                StructField("available_interfaces", ArrayType(StringType()), False),
                                StructField("connectivity", StringType(), False),
                                StructField("downlink_kbps", StringType(), False),
                                StructField("geoip", StructType([
                                    StructField("as", StructType([
                                        StructField("domain", StringType(), False),
                                        StructField("name", StringType(), False),
                                        StructField("number", StringType(), False),
                                        StructField("route", StringType(), False),
                                        StructField("type", StringType(), False)
                                    ]), False),
                                    StructField("city", StructType([
                                        StructField("name", StringType(), False)
                                    ]), False),
                                    StructField("continent", StructType([
                                        StructField("code", StringType(), False),
                                        StructField("name", StringType(), False)
                                    ]), False),
                                    StructField("country", StructType([
                                        StructField("iso_code", StringType(), False),
                                        StructField("name", StringType(), False)
                                    ]), False),
                                    StructField("ipAddress", StringType(), False),
                                    StructField("location", StructType([
                                        StructField("latitude", DoubleType(), False),
                                        StructField("longitude", DoubleType(), False)
                                    ]), False),
                                    StructField("subdivision", StructType([
                                        StructField("iso_code", StringType(), False),
                                        StructField("name", StringType(), False)
                                    ]), False),
                                    StructField("timezone", StringType(), False)
                                ]), False),
                                StructField("ip", StringType(), False),
                                StructField("is_constrained", BooleanType(), False),
                                StructField("is_expensive", BooleanType(), False),
                                StructField("reachability", StringType(), False),
                                StructField("signal_strength", StringType(), False),
                                StructField("sim_carrier", StructType([
                                    StructField("allows_voip", BooleanType(), False),
                                    StructField("iso_country", StringType(), False),
                                    StructField("name", StringType(), False),
                                    StructField("technology", StringType(), False)
                                ]), False),
                                StructField("supports_ipv4", BooleanType(), False),
                                StructField("supports_ipv6", BooleanType(), False),
                                StructField("uplink_kbps", StringType(), False)
                            ]), False)
                        ]), False),
                        StructField("old_service", StringType(), False),
                        StructField("origin", StringType(), False),
                        StructField("os", StructType([
                            StructField("build", StringType(), False),
                            StructField("name", StringType(), False),
                            StructField("version", StringType(), False)
                        ]), False),
                        StructField("permission", StringType(), False),
                        StructField("polling", BooleanType(), False),
                        StructField("retry", BooleanType(), False),
                        StructField("route", StringType(), False),
                        StructField("serasa_product", StringType(), False),
                        StructField("service", StringType(), False),
                        StructField("session_id", StringType(), False),
                        StructField("stack_trace", StringType(), False),
                        StructField("stack_trace_grouping", StringType(), False),
                        StructField("status", StringType(), False),
                        StructField("status_code", StringType(), False),
                        StructField("terms_result", StringType(), False),
                        StructField("unlock", BooleanType(), False),
                        StructField("upload_type", StringType(), False),
                        StructField("user_action", StructType([
                            StructField("id", StringType(), False)
                        ]), False),
                        StructField("user_approved", BooleanType(), False),
                        StructField("user_exit", BooleanType(), False),
                        StructField("user_id", StringType(), False),
                        StructField("usr", StructType([
                            StructField("id", StringType(), False)
                        ]), False),
                        StructField("utm_info", StructType([
                            StructField("deeplink_path", StringType(), False),
                            StructField("gclid", StringType(), False),
                            StructField("has_gclid", BooleanType(), False),
                            StructField("utm_campaign", StringType(), False),
                            StructField("utm_content", StringType(), False),
                            StructField("utm_medium", StringType(), False),
                            StructField("utm_source", StringType(), False),
                            StructField("utm_term", StringType(), False)
                        ]), False),
                        StructField("version", StringType(), False),
                        StructField("view", StructType([
                            StructField("id", StringType(), False),
                            StructField("referrer", StringType(), False),
                            StructField("referrer_details", StructType([
                                StructField("host", StringType(), False),
                                StructField("path", StringType(), False),
                                StructField("queryString", StructType([
                                    StructField("%7Bignore%7Dgclid", StringType(), False),
                                    StructField("_ga", StringType(), False),
                                    StructField("_gl", StringType(), False),
                                    StructField("contactType", StringType(), False),
                                    StructField("cross_content", StringType(), False),
                                    StructField("cross_profile", StringType(), False),
                                    StructField("cross_source", StringType(), False),
                                    StructField("dclid", StringType(), False),
                                    StructField("documentType", StringType(), False),
                                    StructField("fbclid", StringType(), False),
                                    StructField("fill", StringType(), False),
                                    StructField("flow", StringType(), False),
                                    StructField("gad_source", StringType(), False),
                                    StructField("gbraid", StringType(), False),
                                    StructField("gclid", StringType(), False),
                                    StructField("grouper", StringType(), False),
                                    StructField("msclkid", StringType(), False),
                                    StructField("order", StringType(), False),
                                    StructField("param", StringType(), False),
                                    StructField("product", StringType(), False),
                                    StructField("psafe_param", StringType(), False),
                                    StructField("redirectUrl", StringType(), False),
                                    StructField("s%2F%3Fs%2F", StringType(), False),
                                    StructField("s%2F?s%2F", StringType(), False),
                                    StructField("s_refresh_url", StringType(), False),
                                    StructField("s_status_code", StringType(), False),
                                    StructField("sfmc_activity_id", StringType(), False),
                                    StructField("sfmc_activity_name", StringType(), False),
                                    StructField("sfmc_activityid", StringType(), False),
                                    StructField("sfmc_asset_id", StringType(), False),
                                    StructField("sfmc_channel", StringType(), False),
                                    StructField("sfmc_id", StringType(), False),
                                    StructField("sfmc_journey_id", StringType(), False),
                                    StructField("sfmc_journey_name", StringType(), False),
                                    StructField("token", StringType(), False),
                                    StructField("ttclid", StringType(), False),
                                    StructField("type", StringType(), False),
                                    StructField("utm_campaign", StringType(), False),
                                    StructField("utm_content", StringType(), False),
                                    StructField("utm_id", StringType(), False),
                                    StructField("utm_medium", StringType(), False),
                                    StructField("utm_source", StringType(), False),
                                    StructField("utm_term", StringType(), False)
                                ]), False),
                                StructField("scheme", StringType(), False)]), False),
                                StructField("url", StringType(), False),
                                StructField("url_details", StructType([
                                    StructField("host", StringType(), False),
                                    StructField("path", StringType(), False),
                                    StructField("queryString", StructType([
                                        StructField("ID-Grupo", StringType(), False),
                                        StructField("Nome-Campanha", StringType(), False),
                                        StructField("contactType", StringType(), False),
                                        StructField("destinationURL", StringType(), False),
                                        StructField("documentType", StringType(), False),
                                        StructField("fill", StringType(), False),
                                        StructField("flow", StringType(), False),
                                        StructField("msclkid", StringType(), False),
                                        StructField("polling", StringType(), False),
                                        StructField("product", StringType(), False),
                                        StructField("redirectUrl", StringType(), False),
                                        StructField("status", StringType(), False),
                                        StructField("tempToken", StringType(), False),
                                        StructField("token", StringType(), False),
                                        StructField("type", StringType(), False),
                                        StructField("utm_campaign", StringType(), False),
                                        StructField("utm_content", StringType(), False),
                                        StructField("utm_medium", StringType(), False),
                                        StructField("utm_source", StringType(), False),
                                        StructField("utm_term", StringType(), False)
                                    ]), False),
                                    StructField("scheme", StringType(), False)
                                ]), False)
                        ]), False),        
                        StructField("waiting_time", StringType(), False)
                    ])

# %%
attributes_back_schema =  StructType([
            StructField("context", StructType([
            StructField("serasa_product", StringType(), True),
            StructField("eventCode", StringType(), True),
            StructField("log_type", StringType(), True),
            StructField("service", StringType(), True),
            StructField("is_overage", StringType(), True),
            StructField("action", StringType(), True),
            StructField("version", StringType(), True),
            StructField("flow", StringType(), True),
            StructField("flow_version", StringType(), True),
            StructField("client_origin", StructType([
                StructField("device_model", StringType(), True),
                StructField("device_brand", StringType(), True),
                StructField("origin", StringType(), True),
                StructField("os_version", StringType(), True)
            ]), True)
        ]), True),
      StructField("date", LongType(), True),
      StructField("date_time", StringType(), True),
      StructField("event_origin", StructType([
        StructField("client_address", StringType(), True),
        StructField("system", StringType(), True),]), True),
      StructField("fields", StructType([
        StructField("level", StringType(), True),
        StructField("msg", StringType(), True),
        StructField("time", StringType(), True),]), True),
      StructField("key", StringType(), True),
      StructField("sessionId", StringType(), True),
      StructField("log_level", StringType(), True),
      StructField("log_version", StringType(), True),
      StructField("origin", StructType([
        StructField("headers", StructType([
            StructField("Accept", ArrayType(StringType()), True),
            StructField("Accept-Encoding", ArrayType(StringType()), True),
            StructField("Accept-Language", ArrayType(StringType()), True),
            StructField("Authorization", ArrayType(StringType()), True),
            StructField("Cache-Control", ArrayType(StringType()), True),
            StructField("Cdn-Loop", ArrayType(StringType()), True),
            StructField("Cloudfront-Forwarded-Proto", ArrayType(StringType()), True),
            StructField("Cloudfront-Is-Desktop-Viewer", ArrayType(StringType()), True),
            StructField("Cloudfront-Is-Mobile-Viewer", ArrayType(StringType()), True),
            StructField("Cloudfront-Is-Smarttv-Viewer", ArrayType(StringType()), True),
            StructField("Cloudfront-Is-Tablet-Viewer", ArrayType(StringType()), True),
            StructField("Cloudfront-Viewer-Asn", ArrayType(StringType()), True),
            StructField("Cloudfront-Viewer-Country", ArrayType(StringType()), True),
            StructField("Connection", ArrayType(StringType()), True),
            StructField("Content-Length", ArrayType(StringType()), True),
            StructField("Content-Type", ArrayType(StringType()), True),
            StructField("Cookie", ArrayType(StringType()), True),
            StructField("Dnt", ArrayType(StringType()), True),
            StructField("Incap-Client-Ip", ArrayType(StringType()), True),
            StructField("Oec-Vc-Sdk-Version", ArrayType(StringType()), True),
            StructField("Origin", ArrayType(StringType()), True),
            StructField("Priority", ArrayType(StringType()), True),
            StructField("Purpose", ArrayType(StringType()), True),
            StructField("Referer", ArrayType(StringType()), True),
            StructField("Save-Data", ArrayType(StringType()), True),
            StructField("Sec-Ch-Ua", ArrayType(StringType()), True),
            StructField("Sec-Ch-Ua-Mobile", ArrayType(StringType()), True),
            StructField("Sec-Ch-Ua-Platform", ArrayType(StringType()), True),
            StructField("Sec-Fetch-Dest", ArrayType(StringType()), True),
            StructField("Sec-Fetch-Mode", ArrayType(StringType()), True),
            StructField("Sec-Fetch-Site", ArrayType(StringType()), True),
            StructField("Sec-Gpc", ArrayType(StringType()), True),
            StructField("Sec-Purpose", ArrayType(StringType()), True),
            StructField("Traceparent", ArrayType(StringType()), True),
            StructField("Tracestate", ArrayType(StringType()), True),
            StructField("User-Agent", ArrayType(StringType()), True),
            StructField("Via", ArrayType(StringType()), True),
            StructField("X-Amz-Cf-Id", ArrayType(StringType()), True),
            StructField("X-Amzn-Apigateway-Api-Id", ArrayType(StringType()), True),
            StructField("X-Amzn-Trace-Id", ArrayType(StringType()), True),
            StructField("X-Api-Key", ArrayType(StringType()), True),
            StructField("X-B3-Sampled", ArrayType(StringType()), True),
            StructField("X-B3-Spanid", ArrayType(StringType()), True),
            StructField("X-B3-Traceid", ArrayType(StringType()), True),
            StructField("X-Bd-Kmsv", ArrayType(StringType()), True),
            StructField("X-Bifrost-Authorization", ArrayType(StringType()), True),
            StructField("X-Datadog-Origin", ArrayType(StringType()), True),
            StructField("X-Datadog-Parent-Id", ArrayType(StringType()), True),
            StructField("X-Datadog-Sampling-Priority", ArrayType(StringType()), True),
            StructField("X-Datadog-Tags", ArrayType(StringType()), True),
            StructField("X-Datadog-Trace-Id", ArrayType(StringType()), True),
            StructField("X-Dynatrace", ArrayType(StringType()), True),
            StructField("X-Ecs-Application-Id", ArrayType(StringType()), True),
            StructField("X-Ecs-Device-Id", ArrayType(StringType()), True),
            StructField("X-Ecs-Loa-Route", ArrayType(StringType()), True),
            StructField("X-Envoy-Decorator-Operation", ArrayType(StringType()), True),
            StructField("X-Envoy-External-Address", ArrayType(StringType()), True),
            StructField("X-Envoy-Internal", ArrayType(StringType()), True),
            StructField("X-Forwarded-For", ArrayType(StringType()), True),
            StructField("X-Forwarded-Port", ArrayType(StringType()), True),
            StructField("X-Forwarded-Proto", ArrayType(StringType()), True),
            StructField("X-Gorgon", ArrayType(StringType()), True),
            StructField("X-Istio-Attributes", ArrayType(StringType()), True),
            StructField("X-Khronos", ArrayType(StringType()), True),
            StructField("X-Middleware-Subrequest", ArrayType(StringType()), True),
            StructField("X-Proxyuser-Ip", ArrayType(StringType()), True),
            StructField("X-Request-Client", ArrayType(StringType()), True),
            StructField("X-Request-Id", ArrayType(StringType()), True),
            StructField("X-Request-Service", ArrayType(StringType()), True),
            StructField("X-Requested-With", ArrayType(StringType()), True),
            StructField("X-Session-Id", ArrayType(StringType()), True),
            StructField("X-Tt-Bypass-Dp", ArrayType(StringType()), True),
            StructField("X-Tt-Pba-Enable", ArrayType(StringType()), True),
            StructField("X-Tt-Trace-Id", ArrayType(StringType()), True),
            StructField("X-Tt-Web-Proxy", ArrayType(StringType()), True),
            StructField("X-Vc-Bdturing-Sdk-Version", ArrayType(StringType()), True)
        ]), True),
        StructField("ip", StringType(), True), ]), True),
      StructField("process", DoubleType(), True),
      StructField("request_id", StringType(), True),
      StructField("serasa", StructType([
        StructField("product", StructType([
        StructField("application", StringType(), True),
        StructField("channel", StringType(), True),
        StructField("http", StructType([
            StructField("method", StringType(), True),
            StructField("path", StringType(), True),
            StructField("name", StringType(), True),
            StructField("version", StringType(), True)]), True),
      ]), True), ]), True),
      StructField("service", StructType([
              StructField("domain", StringType(), True),
              StructField("name", StringType(), True),
              StructField("version", StringType(), True)
          ]), True),
      StructField("span_id", StringType(), True),
      StructField("statusCode", LongType(), True),
      StructField("trace_id", StringType(), True),
      StructField("user", StructType([
          StructField("token", StringType(), True)
      ]), True),
      StructField("userId", StringType(), True),
      StructField("usr", StructType([
          StructField("id", StringType(), True)
      ]), True),
      StructField("version", StringType(), True),
      StructField("x-ecs-application-id", StringType(), True),
      StructField("x-request-id", StringType(), True),])

# %%
#os que estão comentado são as colunas que não foram encontrada
def df_auth_back(df: DataFrame):
  return(
    df
    .select(
    bronzeToSilver["_id"].alias("cd_id", metadata = {'comment': 'identificação do registro'}),
    bronzeToSilver["attributes.context.flow"].alias("flow", metadata = {'comment': 'fluxo'}),
    bronzeToSilver["attributes.context.flow_version"].alias("flow_version", metadata = {'comment': 'versão do fluxo'}),
    bronzeToSilver["attributes.context.action"].alias("action", metadata = {'comment': 'etapa do fluxo'}),
    bronzeToSilver["date"].alias("ts_event", metadata = {'comment': 'timestamp do registro (yyyy-mm-dd 00:00:00:000.0000)'}),
    to_date(bronzeToSilver["date"]).alias("dt_event", metadata = {'comment': 'data do registro (yyyy-mm-dd)'}), 
    bronzeToSilver["attributes.userId"].alias("cd_uuid", metadata = {'comment': 'identificação do usuário'}),
    #bronzeToSilver[""].alias("temp_session_id", metadata = {'comment': 'id da sessão na área deslogada'}),
    bronzeToSilver["attributes.sessionId"].alias("session_id", metadata = {'comment': 'id da sessão na área logada'}),
    bronzeToSilver["attributes.context.serasa_product"].alias("ds_platform", metadata = {'comment': 'produto'}),
    #bronzeToSilver[""].alias("cd_event", metadata = {'comment': 'identificação do evento'}),
    bronzeToSilver["attributes.context.eventCode"].alias("name_event", metadata = {'comment': 'nome do evento'}),
    bronzeToSilver["attributes.context.client_origin.origin"].alias("ds_client_origin", metadata = {'comment': 'plataforma [app-android, app-ios]'}),
    #bronzeToSilver["attributes."].alias("ds_device_brand", metadata = {'comment': 'marca do aparelho'}),
    bronzeToSilver["attributes.context.client_origin.device_model"].alias("ds_device_model", metadata = {'comment': 'modelo do aparelho'}),
    #bronzeToSilver[""].alias("browser", metadata = {'comment': 'nome do browser'}),
    # bronzeToSilver[""].alias("latitude", metadata = {'comment': 'latitude'}),
    # bronzeToSilver[""].alias("longitude", metadata = {'comment': 'longitude'}),
    # bronzeToSilver[""].alias("ip_address", metadata = {'comment': 'endereço de ip'}),
    # bronzeToSilver[""].alias("domain", metadata = {'comment': 'domínio'}),
    # bronzeToSilver[""].alias("state", metadata = {'comment': 'estado'}),
    # bronzeToSilver[""].alias("city", metadata = {'comment': 'cidade'}),
    # bronzeToSilver[""].alias("country", metadata = {'comment': 'país'}),
    # bronzeToSilver[""].alias("continent", metadata = {'comment': 'continente'}),
    bronzeToSilver["attributes.context.log_type"].alias("log_type", metadata = {'comment': 'tipo de log'}),
    #bronzeToSilver[""].alias("login_type", metadata = {'comment': 'tipo de login'}),
    #bronzeToSilver[""].alias("token_type", metadata = {'comment': 'tipo de token usado no login'}),
    #bronzeToSilver[""].alias("ab_test", metadata = {'comment': 'objeto com dados de teste ab'}),
    #bronzeToSilver[""].alias("app_version", metadata = {'comment': 'versão do app'}),
    #bronzeToSilver[""].alias("dst", metadata = {'comment': 'Serviço de destino, IP, DNS, endpoint etc (log do SIEM)'}),
    #bronzeToSilver[""].alias("src", metadata = {'comment': 'IP ou DNS de origem da requisição (log do SIEM)'}),
    bronzeToSilver["status"].alias("status", metadata = {'comment': 'inf ou erro'})
    #bronzeToSilver[""].alias("event_data", metadata = {'comment': 'objeto com o retorno completo do evento  em formato json'})
)
  )

# %%
def df_auth_front(df: DataFrame):
  return(
    df
    .select(
    bronzeToSilver["_id"].alias("cd_id"),
    bronzeToSilver["attributes.flow"].alias("flow"),
    bronzeToSilver["attributes.flow_version"].alias("flow_version"),
    bronzeToSilver["attributes.action"].alias("action"),
    bronzeToSilver["date"].alias("ts_event"),
    to_date(bronzeToSilver["date"]).alias("dt_event"),
    bronzeToSilver["attributes.user_id"].alias("cd_uuid"),
    #bronzeToSilver[""].alias("temp_session_id"),
    bronzeToSilver["attributes.session_id"].alias("session_id"),
    bronzeToSilver["attributes.serasa_product"].alias("ds_platform"),
    #bronzeToSilver[""].alias("cd_event"),
    bronzeToSilver["attributes.eventCode"].alias("name_event"),
    bronzeToSilver["attributes.http.useragent_details.os.family"].alias("ds_client_origin"),
    bronzeToSilver["attributes.http.useragent_details.device.brand"].alias("ds_device_brand"),
    bronzeToSilver["attributes.http.useragent_details.device.model"].alias("ds_device_model"),
    bronzeToSilver["attributes.http.useragent_details.browser.family"].alias("browser"), 
    bronzeToSilver["attributes.network.client.geoip.location.latitude"].alias("latitude"),
    bronzeToSilver["attributes.network.client.geoip.location.longitude"].alias("longitude"),
    bronzeToSilver["attributes.network.client.geoip.ipAddress"].alias("ip_address"),
    bronzeToSilver["attributes.network.client.geoip.as.domain"].alias("domain"),
    bronzeToSilver["attributes.network.client.geoip.subdivision.name"].alias("state"),
    bronzeToSilver["attributes.network.client.geoip.city.name"].alias("city"),
    bronzeToSilver["attributes.network.client.geoip.country.name"].alias("country"),
    bronzeToSilver["attributes.network.client.geoip.continent.name"].alias("continent"),
    bronzeToSilver["attributes.log_type"].alias("log_type"),
    bronzeToSilver["attributes.login_type"].alias("login_type"),
    bronzeToSilver["attributes.view.url_details.queryString.contactType"].alias("token_type"),
    to_json(bronzeToSilver["attributes.ab_test"]).alias("ab_test"),
    bronzeToSilver["attributes.logger.version"].alias("app_version"),
    bronzeToSilver["attributes.error_key"].alias("error_key"),
    bronzeToSilver["attributes.error_type"].alias("error_type"),
    bronzeToSilver["attributes.error_status_code"].alias("error_status_code"),
    
    #bronzeToSilver[""].alias("dst"),
    #bronzeToSilver[""].alias("src"),
    bronzeToSilver["status"].alias("status")
    #bronzeToSilver[""].alias("event_data")
))

# %%
def criptografia_silver_front(df: DataFrame):
    df = df.withColumn("latitude", encrypt_geocode(col("latitude")).alias("latitude"))\
        .withColumn("longitude", encrypt_geocode(col("longitude")).alias("longitude"))\
        .withColumn("ip_address", encrypt_ip(col("ip_address")).alias("ip_address"))
    return df

# %%
front_schema_tabela = """
cd_id STRING COMMENT 'identificação do registro',
flow STRING COMMENT 'fluxo',
flow_version STRING COMMENT 'versão do fluxo',
action STRING COMMENT 'etapa do fluxo',
ts_event STRING COMMENT 'timestamp do registro (yyyy-mm-dd 00:00:00:000.0000)',
dt_event DATE COMMENT 'data do registro (yyyy-mm-dd)',
cd_uuid STRING COMMENT 'identificação do usuário',
session_id STRING COMMENT 'id da sessão na área logada',
ds_platform STRING COMMENT 'produto',
name_event STRING COMMENT 'nome do evento',
ds_client_origin STRING COMMENT 'plataforma [app-android, app-ios]',
ds_device_brand STRING COMMENT 'marca do aparelho',
ds_device_model STRING COMMENT 'modelo do aparelho',
browser STRING COMMENT 'nome do browser',
latitude STRING COMMENT 'latitude',
longitude STRING COMMENT 'longitude',
ip_address STRING COMMENT 'endereço de ip',
domain STRING COMMENT 'domínio',
state STRING COMMENT 'estado',
city STRING COMMENT 'cidade',
country STRING COMMENT 'país',
continent STRING COMMENT 'continente',
log_type STRING COMMENT 'tipo de log',
login_type STRING COMMENT 'tipo de login',
token_type STRING COMMENT 'tipo de token usado no login',
ab_test STRING COMMENT 'objeto com dados de teste ab',
app_version STRING COMMENT 'versão do app',
status STRING COMMENT 'inf ou erro',
dt_load_silver DATE,
ts_load_silver TIMESTAMP
"""

# %%
back_schema_tabela = """
cd_id STRING COMMENT 'identificação do registro',
flow STRING COMMENT 'fluxo',
flow_version STRING COMMENT 'versão do fluxo',
action STRING COMMENT 'etapa do fluxo',
ts_event STRING COMMENT 'timestamp do registro (yyyy-mm-dd 00:00:00:000.0000)',
dt_event DATE COMMENT 'data do registro (yyyy-mm-dd)',
cd_uuid STRING COMMENT 'identificação do usuário',
session_id STRING COMMENT 'id da sessão na área logada',
ds_platform STRING COMMENT 'produto',
name_event STRING COMMENT 'nome do evento',
ds_client_origin STRING COMMENT 'plataforma [app-android, app-ios]',
ds_device_model STRING COMMENT 'modelo do aparelho',
log_type STRING COMMENT 'tipo de log',
status STRING COMMENT 'inf ou erro',
dt_load_silver DATE,
ts_load_silver TIMESTAMP
"""
